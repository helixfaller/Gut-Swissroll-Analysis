# %%
import swissroll as sr
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
import pandas as pd

# %%
data = pd.read_csv("template.csv", sep=",")

# %%
## hue is Sacrifice Age (month) and splits Genotype
## hue_split is a variable you use to choose between different
## hue values, but let me describe

hues = []
for variable in data["Sacrifice Age (month)"].tolist():
    if variable not in hues:
        hues.append(variable)

print(f"hue = {hues}")
## if hue_split = 0, then hue == 9
print(f"\nhue[0] = {hues[0]}")
## if hue_split = 1, then hue == 11
print(f"\nhue[1] = {hues[1]}")
## with variable hue and hue_split you can choose which group 
## to test against which
# Out:
# hue = [9, 11]
#
# hue[0] = 9
#
# hue[1] = 11

# %%
columns = ["TB_Area_SI_(mm^2)",
           "TB_Area_SI_NInv_(mm^2)",
           "TB_Area_Inv_(mm^2)",
           "MTS_SI_Ninv_(mm^2)",
           "MTS_SI_Inv_(mm^2)",
           "MTS_SI(mm^2)",
           "Body Weight (g)",
           "Liver weight (g)",
           "Liver(g)/Body(g)",
           "Spleen weight (g)",
           "Spleen (g)/Body (g)"]

# %%
for i, column in enumerate(columns):
    plt.figure(i)
    sr.box_plot(columns=column, data=data, genotype=["X", "Y"], hue="Sacrifice Age (month)",
                hue_split=None, test="Mann-Whitney", palette="Set2_r")
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Y_9 v.s. Y_11: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=4.350e+01
# X_9 v.s. X_11: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=1.000e+00 U_stat=3.750e+01
# X_11 v.s. Y_9: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=5.586e-03 U_stat=6.400e+01
# X_9 v.s. Y_9: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=8.675e-03 U_stat=5.600e+01
# X_11 v.s. Y_11: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=2.619e-03 U_stat=8.000e+01
# X_9 v.s. Y_11: Mann-Whitney-Wilcoxon test two-sided with Bonferroni correction, P_val=4.427e-03 U_stat=7.000e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ...
