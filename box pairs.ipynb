# %% [markdown]
# # boxpairs
#
# Jupyter Notebook that gives you an overview on how to use variable hue and hue_split. Depending on these two variables. Depending on these variables, different groups can be tested in the python file swissroll.py.

# %%
import pandas as pd
from itertools import combinations

# %%
data = pd.read_csv("template.csv", sep=",", index_col="Identificiation")
data.head(3)
# Out:
#                  Sacrifice Age (month) Gender (binary)  Gender  Genotype  \
# Identificiation
# Mouse1                               9               m        0        X
# Mouse2                               9               m        0        X
# Mouse3                               9               m        0        X
#
#                  SIT_Num_Inv  SIT_Num_Ninv  SIT_Num_TOT  TB_Area_SI_(mm^2)  \
# Identificiation
# Mouse1                     4             4            8                 86
# Mouse2                     3             5            8                 78
# Mouse3                     5             6           11                195
#
#                  TB_Area_SI_NInv_(mm^2)  TB_Area_Inv_(mm^2)  \
# Identificiation
# Mouse1                               44                  42
# Mouse2                               45                  33
# Mouse3                               59                 136
#
#                  MTS_SI_Ninv_(mm^2)  MTS_SI_Inv_(mm^2)  MTS_SI(mm^2)  \
# Identificiation
# Mouse1                    11.000000               10.5     10.750000
# Mouse2                     9.000000               11.0      9.750000
# Mouse3                     9.833333               27.2     17.727273
#
#                  Body Weight (g)  Liver weight (g)  Liver(g)/Body(g)  \
# Identificiation
# Mouse1                        30              1.14          0.038000
# Mouse2                        28              1.07          0.038214
# Mouse3                        29              0.98          0.033793
#
#                  Spleen weight (g)  Spleen (g)/Body (g)
# Identificiation
# Mouse1                       0.078             0.068421
# Mouse2                       0.086             0.080374
# Mouse3                       0.099             0.101020

# %%
hue = "Sacrifice Age (month)"
genotype = ["X", "Y"]
hue_split = 0

liste_box_pairs = []
if hue == None:
    for i in range(len(genotype)):
        variable = (genotype[i])
        liste_box_pairs.append(variable)
elif hue != None:
    splitting = data[hue].tolist()
    splitting_variables = []
    if hue_split != None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for x in range(len(genotype)):
            variable = (genotype[x], splitting_variables[hue_split])
            liste_box_pairs.append(variable) 
    elif hue_split == None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for i in range(len(splitting_variables)):
            for x in range(len(genotype)):
                variables = (genotype[x], splitting_variables[i])
                liste_box_pairs.append(variables)
    else:
        pass
else:
    pass
box_pairs = list(combinations(liste_box_pairs, 2))

box_pairs
# Out:
# [(('X', 9), ('Y', 9))]

# %%
hue = "Sacrifice Age (month)"
genotype = ["X", "Y"]
hue_split = 1

liste_box_pairs = []
if hue == None:
    for i in range(len(genotype)):
        variable = (genotype[i])
        liste_box_pairs.append(variable)
elif hue != None:
    splitting = data[hue].tolist()
    splitting_variables = []
    if hue_split != None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for x in range(len(genotype)):
            variable = (genotype[x], splitting_variables[hue_split])
            liste_box_pairs.append(variable) 
    elif hue_split == None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for i in range(len(splitting_variables)):
            for x in range(len(genotype)):
                variables = (genotype[x], splitting_variables[i])
                liste_box_pairs.append(variables)
    else:
        pass
else:
    pass
box_pairs = list(combinations(liste_box_pairs, 2))

box_pairs
# Out:
# [(('X', 11), ('Y', 11))]

# %%
hue = "Sacrifice Age (month)"
genotype = ["X", "Y"]
hue_split = None

liste_box_pairs = []
if hue == None:
    for i in range(len(genotype)):
        variable = (genotype[i])
        liste_box_pairs.append(variable)
elif hue != None:
    splitting = data[hue].tolist()
    splitting_variables = []
    if hue_split != None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for x in range(len(genotype)):
            variable = (genotype[x], splitting_variables[hue_split])
            liste_box_pairs.append(variable) 
    elif hue_split == None:
        for variable in splitting:
            if variable not in splitting_variables:
                splitting_variables.append(variable)
            else:
                pass
        for i in range(len(splitting_variables)):
            for x in range(len(genotype)):
                variables = (genotype[x], splitting_variables[i])
                liste_box_pairs.append(variables)
    else:
        pass
else:
    pass
box_pairs = list(combinations(liste_box_pairs, 2))

box_pairs
# Out:
# [(('X', 9), ('Y', 9)),
#  (('X', 9), ('X', 11)),
#  (('X', 9), ('Y', 11)),
#  (('Y', 9), ('X', 11)),
#  (('Y', 9), ('Y', 11)),
#  (('X', 11), ('Y', 11))]
